# %% [markdown]
# <a href="https://colab.research.google.com/github/MichelaPascale/Challenges/blob/main/PrimaProvaChallenge/Notebook_preparazione.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("mushrooms.partial.csv")

# %%
data
# Out:
#      class cap-shape cap-surface  ... spore-print-color population habitat
# 0        p         k           s  ...                 w          v       d
# 1        p         x           s  ...                 w          v       p
# 2        p         f           y  ...                 w          v       l
# 3        e         f           f  ...                 n          v       d
# 4        e         b           y  ...                 n          n       m
# ...    ...       ...         ...  ...               ...        ...     ...
# 6494     p         x           y  ...                 w          v       p
# 6495     e         k           y  ...                 w          c       w
# 6496     e         f           y  ...                 n          y       p
# 6497     p         k           s  ...                 w          v       p
# 6498     e         k           f  ...                 w          n       g
#
# [6499 rows x 23 columns]

# %%
train, test = train_test_split(data,random_state=42,test_size=0.2)    # Suddivisione dei dati in training e test set

# %%
train
# Out:
#      class cap-shape cap-surface  ... spore-print-color population habitat
# 2851     e         x           y  ...                 n          y       p
# 4918     p         x           y  ...                 n          v       u
# 5690     e         f           f  ...                 n          y       d
# 4262     p         k           y  ...                 w          v       l
# 4975     p         f           y  ...                 h          y       d
# ...    ...       ...         ...  ...               ...        ...     ...
# 3772     p         f           f  ...                 h          v       g
# 5191     p         k           s  ...                 w          v       p
# 5226     e         x           s  ...                 n          a       g
# 5390     p         f           s  ...                 w          v       d
# 860      e         f           y  ...                 n          v       d
#
# [5199 rows x 23 columns]

# %%
test
# Out:
#      class cap-shape cap-surface  ... spore-print-color population habitat
# 5572     e         f           s  ...                 w          c       w
# 1703     e         b           f  ...                 w          n       g
# 5862     e         f           y  ...                 w          c       w
# 1773     e         f           s  ...                 k          a       g
# 5709     p         x           s  ...                 h          v       g
# ...    ...       ...         ...  ...               ...        ...     ...
# 4778     p         x           s  ...                 w          v       l
# 3494     p         x           y  ...                 w          v       d
# 624      p         f           y  ...                 r          v       m
# 69       e         f           y  ...                 k          v       d
# 889      e         x           f  ...                 w          s       g
#
# [1300 rows x 23 columns]

# %%
train.to_csv('train.csv', index=False)
test.to_csv('test.csv', index=False)
